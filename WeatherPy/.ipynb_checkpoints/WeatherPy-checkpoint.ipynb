# %% [markdown]
# # WeatherPy
#
# ---
#
# ## Starter Code to Generate Random Geographic Coordinates and a List of Cities

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress

# Impor the OpenWeatherMap API key
from api_keys import weather_api_key

# Import citipy to determine the cities based on latitude and longitude
from citipy import citipy

# %% [markdown]
# ### Generate the Cities List by Using the `citipy` Library

# %%
# Empty list for holding the latitude and longitude combinations
lat_lngs = []

# Empty list for holding the cities names
cities = []

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(f"Number of cities in the list: {len(cities)}")
# Out:
# Number of cities in the list: 625

# %% [markdown]
# ---

# %% [markdown]
# ## Requirement 1: Create Plots to Showcase the Relationship Between Weather Variables and Latitude
#
# ### Use the OpenWeatherMap API to retrieve weather data from the cities list generated in the started code

# %%
# Set the API base URL
url = "http://api.openweathermap.org/data/2.5/weather?units=metric&appid="

# Define an empty list to fetch the weather data for each city
city_data = []

# Print to logger
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data
for i, city in enumerate(cities):
    
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 0

    # Create endpoint URL with each city
    city_url = url + weather_api_key + "&q=" + city
    
    
    # Log the url, record, and set numbers
    print("Processing Record %s of Set %s | %s" % (record_count, set_count, city))

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        # Parse the JSON and retrieve data
        city_weather = requests.get(city_url).json()
    
        # Parse out latitude, longitude, max temp, humidity, cloudiness, wind speed, country, and date
        city_name = city_weather["name"]
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_date = city_weather["dt"]

        # Append the City information into city_data list
        city_data.append({"City": city_name, 
                          "Lat": city_lat, 
                          "Lng": city_lng, 
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass
              
# Indicate that Data Loading is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | ejura
# Processing Record 2 of Set 1 | avarua
# Processing Record 3 of Set 1 | maloy
# Processing Record 4 of Set 1 | ponta do sol
# Processing Record 5 of Set 1 | albany
# Processing Record 6 of Set 1 | waitati
# Processing Record 7 of Set 1 | dingle
# Processing Record 8 of Set 1 | portland
# Processing Record 9 of Set 1 | garh maharaja
# Processing Record 10 of Set 1 | vauvert
# Processing Record 11 of Set 1 | tuktoyaktuk
# Processing Record 12 of Set 1 | praia da vitoria
# Processing Record 13 of Set 1 | esperance
# Processing Record 14 of Set 1 | grand river south east
# City not found. Skipping...
# Processing Record 15 of Set 1 | kaitangata
# Processing Record 16 of Set 1 | rio grande
# Processing Record 17 of Set 1 | busselton
# Processing Record 18 of Set 1 | college
# Processing Record 19 of Set 1 | ushuaia
# Processing Record 20 of Set 1 | grand centre
# City not found. Skipping...
# Processing Record 21 of Set 1 | rikitea
# Processing Record 22 of Set 1 | artyk
# City not found. Skipping...
# Processing Record 23 of Set 1 | hobart
# Processing Record 24 of Set 1 | barrow
# Processing Record 25 of Set 1 | tiksi
# Processing Record 26 of Set 1 | mardin
# Processing Record 27 of Set 1 | chase
# Processing Record 28 of Set 1 | otjimbingwe
# Processing Record 29 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 30 of Set 1 | yirol
# City not found. Skipping...
# Processing Record 31 of Set 1 | seymchan
# Processing Record 32 of Set 1 | arinos
# Processing Record 33 of Set 1 | pangai
# Processing Record 34 of Set 1 | tanabe
# Processing Record 35 of Set 1 | severo-kurilsk
# Processing Record 36 of Set 1 | qaanaaq
# Processing Record 37 of Set 1 | castro
# Processing Record 38 of Set 1 | freeport
# Processing Record 39 of Set 1 | sola
# Processing Record 40 of Set 1 | nizhneyansk
# City not found. Skipping...
# Processing Record 41 of Set 1 | saskylakh
# Processing Record 42 of Set 1 | katsuura
# Processing Record 43 of Set 1 | georgetown
# Processing Record 44 of Set 1 | mataura
# Processing Record 45 of Set 1 | puerto ayora
# Processing Record 46 of Set 1 | longyearbyen
# Processing Record 47 of Set 1 | ribeira grande
# Processing Record 48 of Set 1 | bengkulu
# Processing Record 49 of Set 1 | dzhusaly
# City not found. Skipping...
# Processing Record 50 of Set 1 | kuryk
# Processing Record 0 of Set 2 | losinyy
# Processing Record 1 of Set 2 | punta arenas
# Processing Record 2 of Set 2 | goderich
# Processing Record 3 of Set 2 | cayenne
# Processing Record 4 of Set 2 | norman wells
# Processing Record 5 of Set 2 | yulara
# Processing Record 6 of Set 2 | mount gambier
# Processing Record 7 of Set 2 | broken hill
# Processing Record 8 of Set 2 | jiwani
# Processing Record 9 of Set 2 | la asuncion
# Processing Record 10 of Set 2 | the valley
# Processing Record 11 of Set 2 | saint-philippe
# Processing Record 12 of Set 2 | kautokeino
# Processing Record 13 of Set 2 | acari
# Processing Record 14 of Set 2 | atuona
# Processing Record 15 of Set 2 | airai
# Processing Record 16 of Set 2 | miracema do tocantins
# Processing Record 17 of Set 2 | lompoc
# Processing Record 18 of Set 2 | tuatapere
# Processing Record 19 of Set 2 | kapaa
# Processing Record 20 of Set 2 | djambala
# Processing Record 21 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 22 of Set 2 | hithadhoo
# Processing Record 23 of Set 2 | namibe
# Processing Record 24 of Set 2 | sarkand
# Processing Record 25 of Set 2 | nuuk
# Processing Record 26 of Set 2 | lavrentiya
# Processing Record 27 of Set 2 | avera
# Processing Record 28 of Set 2 | faya
# Processing Record 29 of Set 2 | jamestown
# Processing Record 30 of Set 2 | cascais
# Processing Record 31 of Set 2 | belaya gora
# Processing Record 32 of Set 2 | yerbogachen
# Processing Record 33 of Set 2 | vaini
# Processing Record 34 of Set 2 | bathsheba
# Processing Record 35 of Set 2 | iqaluit
# Processing Record 36 of Set 2 | arraial do cabo
# Processing Record 37 of Set 2 | san cristobal
# Processing Record 38 of Set 2 | oistins
# Processing Record 39 of Set 2 | belyy yar
# Processing Record 40 of Set 2 | port alfred
# Processing Record 41 of Set 2 | oktyabrskiy
# Processing Record 42 of Set 2 | guerrero negro
# Processing Record 43 of Set 2 | fushun
# Processing Record 44 of Set 2 | cape town
# Processing Record 45 of Set 2 | cap malheureux
# Processing Record 46 of Set 2 | pevek
# Processing Record 47 of Set 2 | mahebourg
# Processing Record 48 of Set 2 | kazachinskoye
# Processing Record 49 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 0 of Set 3 | bluff
# Processing Record 1 of Set 3 | hermanus
# Processing Record 2 of Set 3 | sept-iles
# Processing Record 3 of Set 3 | seydi
# Processing Record 4 of Set 3 | caramay
# Processing Record 5 of Set 3 | provideniya
# Processing Record 6 of Set 3 | pangnirtung
# Processing Record 7 of Set 3 | northam
# Processing Record 8 of Set 3 | kawana waters
# City not found. Skipping...
# Processing Record 9 of Set 3 | lar gerd
# City not found. Skipping...
# Processing Record 10 of Set 3 | westport
# Processing Record 11 of Set 3 | coquimbo
# Processing Record 12 of Set 3 | itiuba
# Processing Record 13 of Set 3 | touros
# Processing Record 14 of Set 3 | alofi
# Processing Record 15 of Set 3 | samusu
# City not found. Skipping...
# Processing Record 16 of Set 3 | sao filipe
# Processing Record 17 of Set 3 | asau
# Processing Record 18 of Set 3 | fortuna
# Processing Record 19 of Set 3 | hamilton
# Processing Record 20 of Set 3 | mar del plata
# Processing Record 21 of Set 3 | matara
# Processing Record 22 of Set 3 | thompson
# Processing Record 23 of Set 3 | san pedro
# Processing Record 24 of Set 3 | seoul
# Processing Record 25 of Set 3 | kiama
# Processing Record 26 of Set 3 | ternate
# Processing Record 27 of Set 3 | chuy
# Processing Record 28 of Set 3 | kruisfontein
# Processing Record 29 of Set 3 | hilo
# Processing Record 30 of Set 3 | tasiilaq
# Processing Record 31 of Set 3 | pisco
# Processing Record 32 of Set 3 | lagoa
# Processing Record 33 of Set 3 | beringovskiy
# Processing Record 34 of Set 3 | kutum
# Processing Record 35 of Set 3 | kamaishi
# Processing Record 36 of Set 3 | upernavik
# Processing Record 37 of Set 3 | ziway
# Processing Record 38 of Set 3 | butaritari
# Processing Record 39 of Set 3 | nikolskoye
# Processing Record 40 of Set 3 | necochea
# Processing Record 41 of Set 3 | serenje
# Processing Record 42 of Set 3 | barentsburg
# City not found. Skipping...
# Processing Record 43 of Set 3 | manta
# Processing Record 44 of Set 3 | constitucion
# Processing Record 45 of Set 3 | dikson
# Processing Record 46 of Set 3 | sal rei
# Processing Record 47 of Set 3 | san quintin
# Processing Record 48 of Set 3 | sitka
# Processing Record 49 of Set 3 | chunskiy
# Processing Record 0 of Set 4 | bubaque
# Processing Record 1 of Set 4 | cradock
# Processing Record 2 of Set 4 | chokurdakh
# Processing Record 3 of Set 4 | east london
# Processing Record 4 of Set 4 | lata
# Processing Record 5 of Set 4 | jalu
# Processing Record 6 of Set 4 | sarandi
# Processing Record 7 of Set 4 | port maria
# Processing Record 8 of Set 4 | upata
# Processing Record 9 of Set 4 | schwabmunchen
# Processing Record 10 of Set 4 | ugoofaaru
# Processing Record 11 of Set 4 | morros
# Processing Record 12 of Set 4 | attawapiskat
# City not found. Skipping...
# Processing Record 13 of Set 4 | winnenden
# Processing Record 14 of Set 4 | yellowknife
# Processing Record 15 of Set 4 | karaul
# City not found. Skipping...
# Processing Record 16 of Set 4 | haines junction
# Processing Record 17 of Set 4 | abu dhabi
# Processing Record 18 of Set 4 | bonfim
# Processing Record 19 of Set 4 | kentville
# Processing Record 20 of Set 4 | kampong thum
# Processing Record 21 of Set 4 | lebu
# Processing Record 22 of Set 4 | vallenar
# Processing Record 23 of Set 4 | smolenka
# Processing Record 24 of Set 4 | chicama
# Processing Record 25 of Set 4 | singkang
# Processing Record 26 of Set 4 | bredasdorp
# Processing Record 27 of Set 4 | urdzhar
# City not found. Skipping...
# Processing Record 28 of Set 4 | birjand
# Processing Record 29 of Set 4 | kahului
# Processing Record 30 of Set 4 | lamar
# Processing Record 31 of Set 4 | carnarvon
# Processing Record 32 of Set 4 | motygino
# Processing Record 33 of Set 4 | maldonado
# Processing Record 34 of Set 4 | poddorye
# Processing Record 35 of Set 4 | narsaq
# Processing Record 36 of Set 4 | temiscaming
# Processing Record 37 of Set 4 | saleaula
# City not found. Skipping...
# Processing Record 38 of Set 4 | new norfolk
# Processing Record 39 of Set 4 | labranzagrande
# Processing Record 40 of Set 4 | torbay
# Processing Record 41 of Set 4 | soyo
# Processing Record 42 of Set 4 | acarau
# Processing Record 43 of Set 4 | vaitupu
# City not found. Skipping...
# Processing Record 44 of Set 4 | vila velha
# Processing Record 45 of Set 4 | petropavlovsk-kamchatskiy
# Processing Record 46 of Set 4 | porto nacional
# Processing Record 47 of Set 4 | great falls
# Processing Record 48 of Set 4 | bam
# Processing Record 49 of Set 4 | nishihara
# Processing Record 0 of Set 5 | ossora
# Processing Record 1 of Set 5 | filadelfia
# Processing Record 2 of Set 5 | beachwood
# Processing Record 3 of Set 5 | fauske
# Processing Record 4 of Set 5 | tilichiki
# Processing Record 5 of Set 5 | victoria
# Processing Record 6 of Set 5 | hofn
# Processing Record 7 of Set 5 | san jose
# Processing Record 8 of Set 5 | saint george
# Processing Record 9 of Set 5 | tromso
# Processing Record 10 of Set 5 | pacific grove
# Processing Record 11 of Set 5 | amurzet
# Processing Record 12 of Set 5 | ankara
# Processing Record 13 of Set 5 | mocuba
# Processing Record 14 of Set 5 | nome
# Processing Record 15 of Set 5 | stornoway
# Processing Record 16 of Set 5 | kouango
# Processing Record 17 of Set 5 | awbari
# Processing Record 18 of Set 5 | inta
# Processing Record 19 of Set 5 | aiquile
# Processing Record 20 of Set 5 | fevralsk
# City not found. Skipping...
# Processing Record 21 of Set 5 | tsihombe
# City not found. Skipping...
# Processing Record 22 of Set 5 | krasnyy luch
# Processing Record 23 of Set 5 | mtsensk
# Processing Record 24 of Set 5 | port hardy
# Processing Record 25 of Set 5 | codrington
# Processing Record 26 of Set 5 | tucuman
# Processing Record 27 of Set 5 | kitimat
# Processing Record 28 of Set 5 | marquette
# Processing Record 29 of Set 5 | hasaki
# Processing Record 30 of Set 5 | pilar
# Processing Record 31 of Set 5 | palampur
# Processing Record 32 of Set 5 | puerto del rosario
# Processing Record 33 of Set 5 | kirkuk
# Processing Record 34 of Set 5 | marcona
# City not found. Skipping...
# Processing Record 35 of Set 5 | bokoro
# Processing Record 36 of Set 5 | we
# City not found. Skipping...
# Processing Record 37 of Set 5 | anadyr
# Processing Record 38 of Set 5 | blacksburg
# Processing Record 39 of Set 5 | horsham
# Processing Record 40 of Set 5 | korla
# Processing Record 41 of Set 5 | soma
# Processing Record 42 of Set 5 | alotau
# City not found. Skipping...
# Processing Record 43 of Set 5 | kungurtug
# Processing Record 44 of Set 5 | beloha
# Processing Record 45 of Set 5 | kodiak
# Processing Record 46 of Set 5 | kabanjahe
# Processing Record 47 of Set 5 | bosansko grahovo
# Processing Record 48 of Set 5 | duldurga
# Processing Record 49 of Set 5 | kasongo-lunda
# Processing Record 0 of Set 6 | port augusta
# Processing Record 1 of Set 6 | glendive
# Processing Record 2 of Set 6 | mys shmidta
# City not found. Skipping...
# Processing Record 3 of Set 6 | bambous virieux
# Processing Record 4 of Set 6 | san patricio
# Processing Record 5 of Set 6 | keighley
# Processing Record 6 of Set 6 | khatanga
# Processing Record 7 of Set 6 | mae hong son
# Processing Record 8 of Set 6 | tumen
# Processing Record 9 of Set 6 | byron bay
# Processing Record 10 of Set 6 | sambava
# Processing Record 11 of Set 6 | nemuro
# Processing Record 12 of Set 6 | okhotsk
# Processing Record 13 of Set 6 | meyungs
# City not found. Skipping...
# Processing Record 14 of Set 6 | asyut
# Processing Record 15 of Set 6 | biak
# Processing Record 16 of Set 6 | pochutla
# Processing Record 17 of Set 6 | thinadhoo
# Processing Record 18 of Set 6 | pestretsy
# Processing Record 19 of Set 6 | magadan
# Processing Record 20 of Set 6 | putina
# Processing Record 21 of Set 6 | benghazi
# Processing Record 22 of Set 6 | pontal do parana
# Processing Record 23 of Set 6 | saldanha
# Processing Record 24 of Set 6 | mareeba
# Processing Record 25 of Set 6 | killybegs
# Processing Record 26 of Set 6 | kavieng
# Processing Record 27 of Set 6 | pervoye maya
# Processing Record 28 of Set 6 | safaga
# Processing Record 29 of Set 6 | lavos
# Processing Record 30 of Set 6 | rawson
# Processing Record 31 of Set 6 | trairi
# Processing Record 32 of Set 6 | corrales
# Processing Record 33 of Set 6 | san carlos de bariloche
# Processing Record 34 of Set 6 | antofagasta
# Processing Record 35 of Set 6 | bethel
# Processing Record 36 of Set 6 | diamantino
# Processing Record 37 of Set 6 | aksu
# Processing Record 38 of Set 6 | cherskiy
# Processing Record 39 of Set 6 | cidreira
# Processing Record 40 of Set 6 | bonthe
# Processing Record 41 of Set 6 | lac du bonnet
# Processing Record 42 of Set 6 | carman
# Processing Record 43 of Set 6 | vila
# Processing Record 44 of Set 6 | port lincoln
# Processing Record 45 of Set 6 | bakchar
# Processing Record 46 of Set 6 | voznesenye
# Processing Record 47 of Set 6 | palu
# Processing Record 48 of Set 6 | poum
# Processing Record 49 of Set 6 | havre
# Processing Record 0 of Set 7 | cabo san lucas
# Processing Record 1 of Set 7 | hunza
# City not found. Skipping...
# Processing Record 2 of Set 7 | nouakchott
# Processing Record 3 of Set 7 | talnakh
# Processing Record 4 of Set 7 | amderma
# City not found. Skipping...
# Processing Record 5 of Set 7 | ancud
# Processing Record 6 of Set 7 | moree
# Processing Record 7 of Set 7 | leh
# Processing Record 8 of Set 7 | marau
# Processing Record 9 of Set 7 | matinhos
# Processing Record 10 of Set 7 | lorengau
# Processing Record 11 of Set 7 | pijao
# Processing Record 12 of Set 7 | kamenskoye
# City not found. Skipping...
# Processing Record 13 of Set 7 | tet
# Processing Record 14 of Set 7 | huangnihe
# Processing Record 15 of Set 7 | laguna
# Processing Record 16 of Set 7 | huarmey
# Processing Record 17 of Set 7 | kapiri mposhi
# Processing Record 18 of Set 7 | otradnoye
# Processing Record 19 of Set 7 | chimbote
# Processing Record 20 of Set 7 | labutta
# City not found. Skipping...
# Processing Record 21 of Set 7 | nabire
# Processing Record 22 of Set 7 | itarema
# Processing Record 23 of Set 7 | luderitz
# Processing Record 24 of Set 7 | olafsvik
# Processing Record 25 of Set 7 | hienghene
# Processing Record 26 of Set 7 | kulhudhuffushi
# Processing Record 27 of Set 7 | talcahuano
# Processing Record 28 of Set 7 | lodja
# Processing Record 29 of Set 7 | saint-augustin
# Processing Record 30 of Set 7 | san jeronimo
# Processing Record 31 of Set 7 | ghorawal
# Processing Record 32 of Set 7 | umm kaddadah
# Processing Record 33 of Set 7 | la rioja
# Processing Record 34 of Set 7 | aykhal
# Processing Record 35 of Set 7 | angoram
# Processing Record 36 of Set 7 | khormuj
# City not found. Skipping...
# Processing Record 37 of Set 7 | ruteng
# Processing Record 38 of Set 7 | tombouctou
# Processing Record 39 of Set 7 | half moon bay
# Processing Record 40 of Set 7 | marystown
# Processing Record 41 of Set 7 | hearst
# Processing Record 42 of Set 7 | bayanday
# Processing Record 43 of Set 7 | pangkalanbuun
# Processing Record 44 of Set 7 | flinders
# Processing Record 45 of Set 7 | fort wellington
# Processing Record 46 of Set 7 | evensk
# Processing Record 47 of Set 7 | calbuco
# Processing Record 48 of Set 7 | port elizabeth
# Processing Record 49 of Set 7 | grand gaube
# Processing Record 0 of Set 8 | rio gallegos
# Processing Record 1 of Set 8 | dombasle-sur-meurthe
# Processing Record 2 of Set 8 | auki
# Processing Record 3 of Set 8 | khajuraho
# Processing Record 4 of Set 8 | pirovskoye
# Processing Record 5 of Set 8 | simao
# Processing Record 6 of Set 8 | el balyana
# City not found. Skipping...
# Processing Record 7 of Set 8 | balikpapan
# Processing Record 8 of Set 8 | panorama
# Processing Record 9 of Set 8 | alpena
# Processing Record 10 of Set 8 | alamosa
# Processing Record 11 of Set 8 | montecristo
# Processing Record 12 of Set 8 | fairbanks
# Processing Record 13 of Set 8 | makakilo city
# Processing Record 14 of Set 8 | renfrew
# Processing Record 15 of Set 8 | ellensburg
# Processing Record 16 of Set 8 | tarusa
# Processing Record 17 of Set 8 | ryotsu
# Processing Record 18 of Set 8 | pontianak
# Processing Record 19 of Set 8 | issa
# Processing Record 20 of Set 8 | aleksandrov gay
# Processing Record 21 of Set 8 | quchan
# Processing Record 22 of Set 8 | aguas formosas
# Processing Record 23 of Set 8 | samana
# Processing Record 24 of Set 8 | philippeville
# Processing Record 25 of Set 8 | bilma
# Processing Record 26 of Set 8 | yantzaza
# Processing Record 27 of Set 8 | bereda
# Processing Record 28 of Set 8 | chauk
# Processing Record 29 of Set 8 | juba
# Processing Record 30 of Set 8 | taiyuan
# Processing Record 31 of Set 8 | port-gentil
# Processing Record 32 of Set 8 | buraydah
# Processing Record 33 of Set 8 | maniitsoq
# Processing Record 34 of Set 8 | malwan
# City not found. Skipping...
# Processing Record 35 of Set 8 | batagay-alyta
# Processing Record 36 of Set 8 | santa cruz cabralia
# Processing Record 37 of Set 8 | tongchuan
# Processing Record 38 of Set 8 | shieli
# Processing Record 39 of Set 8 | worthing
# Processing Record 40 of Set 8 | phayao
# Processing Record 41 of Set 8 | geraldton
# Processing Record 42 of Set 8 | ballina
# Processing Record 43 of Set 8 | muravlenko
# Processing Record 44 of Set 8 | sirsaganj
# Processing Record 45 of Set 8 | rungata
# City not found. Skipping...
# Processing Record 46 of Set 8 | taltal
# Processing Record 47 of Set 8 | nouadhibou
# Processing Record 48 of Set 8 | broome
# Processing Record 49 of Set 8 | lolua
# City not found. Skipping...
# Processing Record 0 of Set 9 | narsingdi
# Processing Record 1 of Set 9 | sentyabrskiy
# City not found. Skipping...
# Processing Record 2 of Set 9 | porto uniao
# Processing Record 3 of Set 9 | burewala
# Processing Record 4 of Set 9 | honningsvag
# Processing Record 5 of Set 9 | qaqortoq
# Processing Record 6 of Set 9 | sinnamary
# Processing Record 7 of Set 9 | sao joao dos patos
# Processing Record 8 of Set 9 | zurrieq
# Processing Record 9 of Set 9 | poya
# Processing Record 10 of Set 9 | souillac
# Processing Record 11 of Set 9 | aswan
# Processing Record 12 of Set 9 | paradwip
# City not found. Skipping...
# Processing Record 13 of Set 9 | srednekolymsk
# Processing Record 14 of Set 9 | lebanon
# Processing Record 15 of Set 9 | prince rupert
# Processing Record 16 of Set 9 | moses lake
# Processing Record 17 of Set 9 | harper
# Processing Record 18 of Set 9 | cedar city
# Processing Record 19 of Set 9 | mankovo-kalitvenskoye
# City not found. Skipping...
# Processing Record 20 of Set 9 | ostrovnoy
# Processing Record 21 of Set 9 | martvili
# Processing Record 22 of Set 9 | kieta
# Processing Record 23 of Set 9 | palana
# Processing Record 24 of Set 9 | samatau
# City not found. Skipping...
# Processing Record 25 of Set 9 | bayan
# Processing Record 26 of Set 9 | irara
# Processing Record 27 of Set 9 | gospic
# Processing Record 28 of Set 9 | ayan
# Processing Record 29 of Set 9 | katherine
# Processing Record 30 of Set 9 | polis
# Processing Record 31 of Set 9 | porto torres
# Processing Record 32 of Set 9 | alta floresta
# Processing Record 33 of Set 9 | adrar
# Processing Record 34 of Set 9 | tsentralnyy
# City not found. Skipping...
# Processing Record 35 of Set 9 | mokhsogollokh
# Processing Record 36 of Set 9 | comana
# Processing Record 37 of Set 9 | faanui
# Processing Record 38 of Set 9 | zalantun
# Processing Record 39 of Set 9 | igarka
# Processing Record 40 of Set 9 | kumluca
# Processing Record 41 of Set 9 | kidal
# Processing Record 42 of Set 9 | mariental
# Processing Record 43 of Set 9 | nam dinh
# Processing Record 44 of Set 9 | ginda
# Processing Record 45 of Set 9 | aiken
# Processing Record 46 of Set 9 | high level
# Processing Record 47 of Set 9 | merauke
# Processing Record 48 of Set 9 | meulaboh
# Processing Record 49 of Set 9 | palabuhanratu
# City not found. Skipping...
# Processing Record 0 of Set 10 | lazarev
# Processing Record 1 of Set 10 | clyde river
# Processing Record 2 of Set 10 | bargal
# City not found. Skipping...
# Processing Record 3 of Set 10 | haukipudas
# Processing Record 4 of Set 10 | emba
# Processing Record 5 of Set 10 | aripuana
# Processing Record 6 of Set 10 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 7 of Set 10 | nerchinskiy zavod
# Processing Record 8 of Set 10 | sosnogorsk
# Processing Record 9 of Set 10 | homestead
# Processing Record 10 of Set 10 | leningradskiy
# Processing Record 11 of Set 10 | den helder
# Processing Record 12 of Set 10 | champerico
# Processing Record 13 of Set 10 | taoudenni
# Processing Record 14 of Set 10 | santa flavia
# Processing Record 15 of Set 10 | santa maria
# Processing Record 16 of Set 10 | lagunas
# Processing Record 17 of Set 10 | tiznit
# Processing Record 18 of Set 10 | benemerito de las americas
# Processing Record 19 of Set 10 | isangel
# Processing Record 20 of Set 10 | ladario
# Processing Record 21 of Set 10 | preobrazheniye
# Processing Record 22 of Set 10 | labuhan
# Processing Record 23 of Set 10 | hopatcong
# Processing Record 24 of Set 10 | magnolia
# Processing Record 25 of Set 10 | grants pass
# Processing Record 26 of Set 10 | zhigansk
# Processing Record 27 of Set 10 | pleasanton
# Processing Record 28 of Set 10 | astoria
# Processing Record 29 of Set 10 | kirakira
# Processing Record 30 of Set 10 | sangar
# Processing Record 31 of Set 10 | komsomolskiy
# Processing Record 32 of Set 10 | guamuchil
# Processing Record 33 of Set 10 | shache
# Processing Record 34 of Set 10 | coihaique
# Processing Record 35 of Set 10 | vila franca do campo
# Processing Record 36 of Set 10 | mogadishu
# Processing Record 37 of Set 10 | saint anthony
# Processing Record 38 of Set 10 | saraland
# Processing Record 39 of Set 10 | nanortalik
# Processing Record 40 of Set 10 | mauriti
# Processing Record 41 of Set 10 | veraval
# Processing Record 42 of Set 10 | karakendzha
# City not found. Skipping...
# Processing Record 43 of Set 10 | pangody
# Processing Record 44 of Set 10 | wewak
# Processing Record 45 of Set 10 | caraquet
# Processing Record 46 of Set 10 | launceston
# Processing Record 47 of Set 10 | quime
# Processing Record 48 of Set 10 | toamasina
# Processing Record 49 of Set 10 | eyl
# Processing Record 0 of Set 11 | deer lake
# Processing Record 1 of Set 11 | arosa
# Processing Record 2 of Set 11 | valparaiso
# Processing Record 3 of Set 11 | guipavas
# Processing Record 4 of Set 11 | jinchang
# Processing Record 5 of Set 11 | kachikau
# City not found. Skipping...
# Processing Record 6 of Set 11 | coos bay
# Processing Record 7 of Set 11 | alipur
# Processing Record 8 of Set 11 | kotido
# Processing Record 9 of Set 11 | roma
# Processing Record 10 of Set 11 | tonantins
# Processing Record 11 of Set 11 | sao joao da barra
# Processing Record 12 of Set 11 | waddan
# Processing Record 13 of Set 11 | elizabeth city
# Processing Record 14 of Set 11 | armeria
# Processing Record 15 of Set 11 | nelson bay
# Processing Record 16 of Set 11 | toora-khem
# Processing Record 17 of Set 11 | inirida
# Processing Record 18 of Set 11 | la libertad
# Processing Record 19 of Set 11 | matamoros
# Processing Record 20 of Set 11 | flin flon
# Processing Record 21 of Set 11 | shakawe
# Processing Record 22 of Set 11 | kaeo
# Processing Record 23 of Set 11 | minab
# Processing Record 24 of Set 11 | porto novo
# Processing Record 25 of Set 11 | guanica
# Processing Record 26 of Set 11 | maiduguri
# Processing Record 27 of Set 11 | sibu
# Processing Record 28 of Set 11 | boden
# Processing Record 29 of Set 11 | egvekinot
# Processing Record 30 of Set 11 | novoilinsk
# Processing Record 31 of Set 11 | singaraja
# Processing Record 32 of Set 11 | demba
# Processing Record 33 of Set 11 | oriximina
# Processing Record 34 of Set 11 | ilulissat
# Processing Record 35 of Set 11 | amahai
# Processing Record 36 of Set 11 | pitimbu
# Processing Record 37 of Set 11 | umzimvubu
# City not found. Skipping...
# Processing Record 38 of Set 11 | itoman
# Processing Record 39 of Set 11 | the pas
# Processing Record 40 of Set 11 | yumen
# Processing Record 41 of Set 11 | takoradi
# Processing Record 42 of Set 11 | almonte
# Processing Record 43 of Set 11 | aklavik
# Processing Record 44 of Set 11 | misratah
# Processing Record 45 of Set 11 | balingasay
# Processing Record 46 of Set 11 | gulshat
# City not found. Skipping...
# Processing Record 47 of Set 11 | emerald
# Processing Record 48 of Set 11 | portree
# Processing Record 49 of Set 11 | cumra
# Processing Record 0 of Set 12 | falun
# Processing Record 1 of Set 12 | burnie
# Processing Record 2 of Set 12 | halifax
# Processing Record 3 of Set 12 | kabinda
# Processing Record 4 of Set 12 | saint albans
# Processing Record 5 of Set 12 | albion
# Processing Record 6 of Set 12 | bitkine
# Processing Record 7 of Set 12 | daosa
# City not found. Skipping...
# Processing Record 8 of Set 12 | salina cruz
# Processing Record 9 of Set 12 | sur
# Processing Record 10 of Set 12 | menongue
# Processing Record 11 of Set 12 | ahipara
# Processing Record 12 of Set 12 | andapa
# Processing Record 13 of Set 12 | nelson
# Processing Record 14 of Set 12 | taksimo
# Processing Record 15 of Set 12 | catuday
# Processing Record 16 of Set 12 | bolungarvik
# City not found. Skipping...
# Processing Record 17 of Set 12 | mingyue
# Processing Record 18 of Set 12 | verkhnevilyuysk
# Processing Record 19 of Set 12 | kandalaksha
# Processing Record 20 of Set 12 | salinas
# Processing Record 21 of Set 12 | vao
# Processing Record 22 of Set 12 | digras
# Processing Record 23 of Set 12 | yiyang
# Processing Record 24 of Set 12 | caravelas
# Processing Record 25 of Set 12 | langxiang
# Processing Record 26 of Set 12 | kenai
# Processing Record 27 of Set 12 | tacuarembo
# Processing Record 28 of Set 12 | groningen
# Processing Record 29 of Set 12 | unity
# Processing Record 30 of Set 12 | maraba
# Processing Record 31 of Set 12 | forestville
# Processing Record 32 of Set 12 | samalaeulu
# City not found. Skipping...
# Processing Record 33 of Set 12 | cherkasskoye
# Processing Record 34 of Set 12 | dejen
# Processing Record 35 of Set 12 | bow island
# Processing Record 36 of Set 12 | nguiu
# City not found. Skipping...
# Processing Record 37 of Set 12 | lotoshino
# Processing Record 38 of Set 12 | port harcourt
# Processing Record 39 of Set 12 | huancabamba
# Processing Record 40 of Set 12 | hualmay
# Processing Record 41 of Set 12 | gouyave
# Processing Record 42 of Set 12 | atambua
# Processing Record 43 of Set 12 | aktau
# Processing Record 44 of Set 12 | etchojoa
# Processing Record 45 of Set 12 | kununurra
# Processing Record 46 of Set 12 | kanadey
# Processing Record 47 of Set 12 | karaidel
# Processing Record 48 of Set 12 | tahta
# Processing Record 49 of Set 12 | calabozo
# Processing Record 0 of Set 13 | luwuk
# Processing Record 1 of Set 13 | sioux lookout
# Processing Record 2 of Set 13 | dickinson
# Processing Record 3 of Set 13 | ostersund
# Processing Record 4 of Set 13 | littleton
# Processing Record 5 of Set 13 | bemidji
# Processing Record 6 of Set 13 | ulladulla
# Processing Record 7 of Set 13 | wick
# Processing Record 8 of Set 13 | tumannyy
# City not found. Skipping...
# Processing Record 9 of Set 13 | libertador general san martin
# Processing Record 10 of Set 13 | klaksvik
# Processing Record 11 of Set 13 | oxford
# Processing Record 12 of Set 13 | longlac
# City not found. Skipping...
# Processing Record 13 of Set 13 | neyshabur
# Processing Record 14 of Set 13 | tambul
# City not found. Skipping...
# Processing Record 15 of Set 13 | bud
# Processing Record 16 of Set 13 | meadow lake
# Processing Record 17 of Set 13 | fonte boa
# Processing Record 18 of Set 13 | yining
# Processing Record 19 of Set 13 | peterhead
# Processing Record 20 of Set 13 | baykalsk
# Processing Record 21 of Set 13 | brae
# Processing Record 22 of Set 13 | gormi
# City not found. Skipping...
# Processing Record 23 of Set 13 | osypenko
# Processing Record 24 of Set 13 | tautira
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the cities weather data into a Pandas DataFrame
city_data_df = pd.DataFrame(city_data)

# Show Record Count
city_data_df.count()
# Out:
# City          571
# Lat           571
# Lng           571
# Max Temp      571
# Humidity      571
# Cloudiness    571
# Wind Speed    571
# Country       571
# Date          571
# dtype: int64

# %%
# Display sample data
city_data_df.head()
# Out:
#            City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0         Ejura   7.3856   -1.3562     21.44        66          21
# 1        Avarua -21.2078 -159.7750     25.03        65          13
# 2         Måløy  61.9353    5.1136      3.18        67          88
# 3  Ponta do Sol  32.6667  -17.1000     16.35        73          13
# 4        Albany  42.6001  -73.9662     -0.99        88         100
#
#    Wind Speed Country        Date
# 0        1.29      GH  1673671312
# 1        2.57      CK  1673671313
# 2        6.28      NO  1673671481
# 3        2.84      PT  1673671315
# 4        0.45      US  1673671258

# %%
# Export the City_Data into a csv
city_data_df.to_csv("output_data/cities.csv", index_label="City_ID")

# %%
# Read saved data
city_data_df = pd.read_csv("output_data/cities.csv", index_col="City_ID")

# Display sample data
city_data_df.head()
# Out:
#                  City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0               Ejura   7.3856   -1.3562     21.44        66          21
# 1              Avarua -21.2078 -159.7750     25.03        65          13
# 2               Måløy  61.9353    5.1136      3.18        67          88
# 3        Ponta do Sol  32.6667  -17.1000     16.35        73          13
# 4              Albany  42.6001  -73.9662     -0.99        88         100
#
#          Wind Speed Country        Date
# City_ID
# 0              1.29      GH  1673671312
# 1              2.57      CK  1673671313
# 2              6.28      NO  1673671481
# 3              2.84      PT  1673671315
# 4              0.45      US  1673671258

# %% [markdown]
# ### Create the Scatter Plots Requested
#
# #### Latitude Vs. Temperature

# %%
# Build scatter plot for latitude vs. temperature
plt.figure(figsize=(9,5))
plt.scatter(city_data_df["Lat"],city_data_df["Max Temp"], marker = "o", facecolors="aqua", edgecolors="black",alpha=0.75)

# Incorporate the other graph properties

plt.title("City Max Latitude vs Temprature",fontsize=16)
plt.xlabel("Latitude",fontsize=12)
plt.ylabel("Max temprature(C)",fontsize=12)
plt.grid()
# Save the figure
plt.savefig("output_data/LatitudevsTemprature.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Humidity

# %%
# Build the scatter plots for latitude vs. humidity
plt.figure(figsize=(9,5))
plt.scatter(city_data_df["Lat"],city_data_df["Humidity"], marker = "o", facecolors="aqua", edgecolors="black",alpha=0.75)


# Incorporate the other graph properties
plt.title("City Latitude vs Humidity",fontsize=16)
plt.xlabel("Latitude",fontsize=12)
plt.ylabel("Humidity (%)",fontsize=12)
plt.grid()

# Save the figure
plt.savefig("output_data/LatitudevsHumidity.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Cloudiness

# %%
# Build the scatter plots for latitude vs. cloudiness
plt.figure(figsize=(9,5))
plt.scatter(city_data_df["Lat"],city_data_df["Cloudiness"], marker = "o", facecolors="aqua", edgecolors="black",alpha=0.75)

# Incorporate the other graph properties
plt.title("City Latitude vs Cloudiness",fontsize=16)
plt.xlabel("Latitude",fontsize=12)
plt.ylabel("Cloudiness (%)",fontsize=12)
plt.grid()

# Save the figure
plt.savefig("output_data/LatitudevsCloudiness.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Build the scatter plots for latitude vs. wind speed
plt.figure(figsize=(9,5))
plt.scatter(city_data_df["Lat"],city_data_df["Wind Speed"], marker = "o", facecolors="aqua", edgecolors="black",alpha=0.75)


# Incorporate the other graph properties
plt.title("City Latitude vs Wind Speed",fontsize=16)
plt.xlabel("Latitude",fontsize=12)
plt.ylabel("Wind Speed(m/s)",fontsize=12)
plt.grid()


# Save the figure
plt.savefig("output_data/LatitudevsWindSpeed.png")

# Show plot
plt.show()

# %% [markdown]
# ---
#
# ## Requirement 2: Compute Linear Regression for Each Relationship

# %%
# Create a DataFrame with the Northern Hemisphere data (Latitude >= 0)
northern_hemi_df=city_data_df.loc[city_data_df["Lat"] >= 0]

# Display sample data
northern_hemi_df.head()
# Out:
#                  City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0               Ejura   7.3856   -1.3562     21.44        66          21
# 2               Måløy  61.9353    5.1136      3.18        67          88
# 3        Ponta do Sol  32.6667  -17.1000     16.35        73          13
# 4              Albany  42.6001  -73.9662     -0.99        88         100
# 6              Dingle  10.9995  122.6711     26.74        85          89
#
#          Wind Speed Country        Date
# City_ID
# 0              1.29      GH  1673671312
# 2              6.28      NO  1673671481
# 3              2.84      PT  1673671315
# 4              0.45      US  1673671258
# 6              4.05      PH  1673671317

# %%
# Create a DataFrame with the Southern Hemisphere data (Latitude < 0)
southern_hemi_df=city_data_df.loc[city_data_df["Lat"]< 0 ]

# Display sample data
southern_hemi_df.head()
# Out:
#                City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 1            Avarua -21.2078 -159.7750     25.03        65          13
# 5           Waitati -45.7500  170.5667     17.11        67          65
# 12        Esperance -33.8667  121.9000     18.59        51          14
# 13       Kaitangata -46.2817  169.8464     16.14        54          19
# 14       Rio Grande -32.0350  -52.0986     20.83        93         100
#
#          Wind Speed Country        Date
# City_ID
# 1              2.57      CK  1673671313
# 5              2.45      NZ  1673671483
# 12             8.48      AU  1673671488
# 13             3.55      NZ  1673671489
# 14             6.89      BR  1673671490

# %% [markdown]
# ###  Temperature vs. Latitude Linear Regression Plot

# %%
# Linear regression on Northern Hemisphere
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Max Temp"]
plt.figure(figsize=(9,5))
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(5.8,0.8),fontsize=15,color="blue")
plt.scatter(x_values,y_values, marker = "o", facecolors="aqua", edgecolors="black",alpha=0.75)
plt.xlabel("Latitude")
plt.ylabel("Max Temp")
print(f"The r-value is:{rvalue}")
plt.show()
# Out:
# The r-value is:-0.8203516437229305

# %%
# Linear regression on Southern Hemisphere
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Max Temp"]
plt.figure(figsize=(9,5))
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(-50,25),fontsize=15,color="blue")
plt.scatter(x_values,y_values, marker = "o", facecolors="aqua", edgecolors="black",alpha=0.75)
plt.xlabel("Latitude")
plt.ylabel("Max Temp")
print(f"The r-value is:{rvalue}")
plt.show()
# Out:
# The r-value is:0.3554624053877048

# %% [markdown]
# **Discussion about the linear relationship:**
# The Max Temperature vs. Latitude plot for cities in the southern and northern hemisphere is shown above.
# The Max Temp appears to show strong negative leinear relation with Latitude in northern hemisphere where as for southern hemisphere there is strong positive linear relation between Latitude and Max Temp.

# %% [markdown]
# ### Humidity vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere

x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Humidity"]
plt.figure(figsize=(9,5))
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(5,50),fontsize=15,color="blue")
plt.scatter(x_values,y_values, marker = "o", facecolors="aqua", edgecolors="black",alpha=0.75)
plt.xlabel("Latitude")
plt.ylabel("Humidity")
print(f"The r-value is:{rvalue}")
plt.show()
# Out:
# The r-value is:0.42956290032157857

# %%
# Southern Hemisphere
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Humidity"]
plt.figure(figsize=(9,5))
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(-50,20),fontsize=15,color="blue")
plt.scatter(x_values,y_values, marker = "o", facecolors="aqua", edgecolors="black",alpha=0.75)
plt.xlabel("Latitude")
plt.ylabel("Humidity")
print(f"The r-value is:{rvalue}")
plt.show()
# Out:
# The r-value is:0.2952098649271102

# %% [markdown]
# **Discussion about the linear relationship:**
# The Humidity vs. Latitude plot for cities in the southern and northern hemisphere is shown above.
# These graph shows moderate postive linear relation between Humidity and Latitiude for both northern and southern hemispehre.

# %% [markdown]
# ### Cloudiness vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Cloudiness"]
plt.figure(figsize=(9,5))
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(50,60),fontsize=15,color="blue")
plt.scatter(x_values,y_values, marker = "o", facecolors="aqua", edgecolors="black",alpha=0.75)
plt.xlabel("Latitude")
plt.ylabel("Cloudiness")
print(f"The r-value is:{rvalue}")
plt.show()
# Out:
# The r-value is:0.3885021826390204

# %%
# Southern Hemisphere
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Cloudiness"]
plt.figure(figsize=(9,5))
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(-50,50),fontsize=15,color="blue")
plt.scatter(x_values,y_values, marker = "o", facecolors="aqua", edgecolors="black",alpha=0.75)
plt.xlabel("Latitude")
plt.ylabel("Cloudiness")
print(f"The r-value is:{rvalue}")
plt.show()
# Out:
# The r-value is:0.3744609788946139

# %% [markdown]
# **Discussion about the linear relationship:**
# The Cloudiness vs. Latitude plot for cities in the southern and northern hemisphere is shown above.
# The data seems to show no linear relationship between Cloudiness and Latitude for both northern and southern hemisphere. Data is very much scattred for cloudiness over the latitude.

# %% [markdown]
# ### Wind Speed vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Wind Speed"]
plt.figure(figsize=(9,5))
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(10,12),fontsize=15,color="blue")
plt.scatter(x_values,y_values, marker = "o", facecolors="aqua", edgecolors="black",alpha=0.75)
plt.xlabel("Latitude")
plt.ylabel("Wind Speed")
print(f"The r-value is:{rvalue}")
plt.show()
# Out:
# The r-value is:0.12946666784684213

# %%
# Southern Hemisphere
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Wind Speed"]
plt.figure(figsize=(9,5))
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(-50,12),fontsize=15,color="blue")
plt.scatter(x_values,y_values, marker = "o", facecolors="aqua", edgecolors="black",alpha=0.75)
plt.xlabel("Latitude")
plt.ylabel("Wind Speed")
print(f"The r-value is:{rvalue}")
plt.show()
# Out:
# The r-value is:-0.4170694710350561

# %% [markdown]
# **Discussion about the linear relationship:**
# The Wind Speed vs. Latitude plot for cities in the southern and northern hemisphere is shown above.
# Data seems to show no relationship for northern hemisphere, whereas for southerns hemisphere there is a weak negative corelation between wind speed and latitude.
