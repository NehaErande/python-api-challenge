# %% [markdown]
# # VacationPy
# ---
#
# ## Starter Code to Import Libraries and Load the Weather and Coordinates Data

# %%
# Dependencies and Setup
import hvplot.pandas
import pandas as pd
import requests
import gmaps
import matplotlib.pyplot as plt
import numpy as np
import json
# Import API key
from api_keys import geoapify_key

# %%
# Load the CSV file created in Part 1 into a Pandas DataFrame
city_data_df = pd.read_csv("../output_data/cities.csv")

# Display sample data
city_data_df.head()
# Out:
#    City_ID       City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0        0  Busselton -33.6500  115.3333     22.63        45           0
# 1        1    Chimoio -19.1164   33.4833     18.58        98          74
# 2        2      Tiksi  71.6872  128.8694    -34.07       100          95
# 3        3   Fairmont  39.4851  -80.1426      6.33        90         100
# 4        4      Vaini -21.2000 -175.2000     31.09        70          75
#
#    Wind Speed Country        Date
# 0        5.47      AU  1674089617
# 1        0.87      MZ  1674089618
# 2        0.11      RU  1674089619
# 3        0.77      US  1674089620
# 4        3.60      TO  1674089621

# %% [markdown]
# ---
#
# ### Step 1: Create a map that displays a point for every city in the `city_data_df` DataFrame. The size of the point should be the humidity in each city.

# %%
# 
gmaps.configure(api_key=geoapify_key)

# %%
# Target city
target_city = city_data_df["City"]

# Build the endpoint URL
target_url = f"https://api.geoapify.com/v1/geocode/search?text={target_city}&format=json&api_key={geoapify_key}"
geo_data = requests.get(target_url).json()
print(json.dumps(geo_data, indent=4, sort_keys=True))
# Extract latitude and longitude
# Out:
# {
#     "query": {
#         "text": "0      Busselton\n1        Chimoio\n2          Tiksi\n3       Fairmont\n4          Vaini\n         ...    \n535        Kathu\n536          Soe\n537     Cabedelo\n538        Kimbe\n539    Rovaniemi\nName: City, Length: 540, dtype: object"
#     },
#     "results": []
# }

# %%
# %%capture --no-display



# Configure the map plot
humidity_map = city_data_df.hvplot.points(
    "Lat","Lng",geo = True,size = "Humidity",color="City",tiles="OSM",frame_width = 500,
    frame_height = 300)

# Display the map
humidity_map
# Out:
# :Overlay
#    .Tiles.I  :Tiles   [x,y]
#    .Points.I :Points   [Lat,Lng]   (City,Humidity)

# %% [markdown]
# ### Step 2: Narrow down the `city_data_df` DataFrame to find your ideal weather condition

# %%
# Narrow down cities that fit criteria and drop any results with null values
# no cloudiness
cloud_df = city_data_df[city_data_df["Cloudiness"]==0]
temp_df = city_data_df[(city_data_df["Max Temp"] > 21) & (city_data_df["Max Temp"] < 27)]
wind_df = temp_df[temp_df["Wind Speed"] < 4.5]

# Drop any rows with null values
wind_df = wind_df.dropna()

# Display sample data
wind_df
# Out:
#      City_ID         City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 12        12         Esim   4.8699   -2.2405     25.84        86          95
# 15        15   Mossamedes -15.1961   12.1522     23.16        73         100
# 16        16  Las Choapas  17.9333  -94.0833     23.08        86           2
# 19        19      Cayenne   4.9333  -52.3333     23.02        94         100
# 20        20      Rikitea -23.1203 -134.9692     25.55        69         100
# ..       ...          ...      ...       ...       ...       ...         ...
# 529      529        Maraã  -1.8333  -65.3667     22.05        97          73
# 530      530  Thohoyandou -22.9456   30.4850     21.31        66         100
# 535      535        Kathu   7.9178   98.3332     24.90        77          74
# 536      536          Soe  -9.8607  124.2840     23.94        73         100
# 538      538        Kimbe  -5.5502  150.1429     25.58        89         100
#
#      Wind Speed Country        Date
# 12         3.09      GH  1674089627
# 15         2.48      AO  1674089629
# 16         1.69      MX  1674089467
# 19         0.00      GF  1674089436
# 20         0.73      PF  1674089632
# ..          ...     ...         ...
# 529        1.24      BR  1674090117
# 530        0.38      ZA  1674090119
# 535        4.20      TH  1674089926
# 536        1.39      ID  1674090124
# 538        1.73      PG  1674090127
#
# [113 rows x 10 columns]

# %% [markdown]
# ### Step 3: Create a new DataFrame called `hotel_df`.

# %%
# Use the Pandas copy function to create DataFrame called hotel_df to store the city, country, coordinates, and humidity
hotel_df = wind_df[['City','Country','Lat','Lng','Humidity']].copy()
# Add an empty column, "Hotel Name," to the DataFrame so you can store the hotel found using the Geoapify API
hotel_df['Hotel Name']= ""

# Display sample data
hotel_df
# Out:
#             City Country      Lat       Lng  Humidity Hotel Name
# 12          Esim      GH   4.8699   -2.2405        86
# 15    Mossamedes      AO -15.1961   12.1522        73
# 16   Las Choapas      MX  17.9333  -94.0833        86
# 19       Cayenne      GF   4.9333  -52.3333        94
# 20       Rikitea      PF -23.1203 -134.9692        69
# ..           ...     ...      ...       ...       ...        ...
# 529        Maraã      BR  -1.8333  -65.3667        97
# 530  Thohoyandou      ZA -22.9456   30.4850        66
# 535        Kathu      TH   7.9178   98.3332        77
# 536          Soe      ID  -9.8607  124.2840        73
# 538        Kimbe      PG  -5.5502  150.1429        89
#
# [113 rows x 6 columns]

# %% [markdown]
# ### Step 4: For each city, use the Geoapify API to find the first hotel located within 10,000 metres of your coordinates.

# %%
# Set parameters to search for a hotel
radius = 10000
# filters = f"circle:{lng},{lat},{radius}"
# bias = f"proximity:{lng},{lat}"
params = {
    "radius": 10000,
    "types": "hotel",
    "keyword": "hotels",
    "apikey": geoapify_key
}

# Print a message to follow up the hotel search
print("Starting hotel search")

# Iterate through the hotel_df DataFrame
for index, row in hotel_df.iterrows():
    # get latitude, longitude from the DataFrame
    lat = row["Lat"]
    lng = row["Lng"]
    
    # Add filter and bias parameters with the current city's latitude and longitude to the params dictionary
    params["filter"] = f"circle:{lng},{lat},{radius}"
    params["bias"] = f"proximity:{lng},{lat}"
    
    # Set base URL
    base_url = "https://api.geoapify.com/v2/places"


    # Make and API request using the params dictionaty
    name_address = requests.get(base_url,params=params)

    
    # Convert the API response to JSON format
    name_address = name_address.json()
    
    # Grab the first hotel from the results and store the name in the hotel_df DataFrame
    try:
        hotel_df.loc[index, "Hotel Name"] = name_address["features"][0]["properties"]["name"]
    except (KeyError, IndexError):
        # If no hotel is found, set the hotel name as "No hotel found".
        hotel_df.loc[index, "Hotel Name"] = "No hotel found"
        
    # Log the search results
    print(f"{hotel_df.loc[index, 'City']} - nearest hotel: {hotel_df.loc[index, 'Hotel Name']}")

# Display sample data
hotel_df
# Out:
# Starting hotel search
# Esim - nearest hotel: No hotel found
# Mossamedes - nearest hotel: No hotel found
# Las Choapas - nearest hotel: No hotel found
# Cayenne - nearest hotel: No hotel found
# Rikitea - nearest hotel: No hotel found
# Mataura - nearest hotel: No hotel found
# George Town - nearest hotel: No hotel found
# Velasco Ibarra - nearest hotel: No hotel found
# Bahía Blanca - nearest hotel: No hotel found
# Hambantota - nearest hotel: No hotel found
# Kapaa - nearest hotel: No hotel found
# Port Alfred - nearest hotel: No hotel found
# East London - nearest hotel: No hotel found
# Comodoro Rivadavia - nearest hotel: No hotel found
# Chui - nearest hotel: No hotel found
# Seaforth - nearest hotel: No hotel found
# Mananjary - nearest hotel: No hotel found
# San Isidro - nearest hotel: No hotel found
# Piaçabuçu - nearest hotel: No hotel found
# Port Elizabeth - nearest hotel: No hotel found
# Aripuanã - nearest hotel: No hotel found
# Jizan - nearest hotel: No hotel found
# Padang - nearest hotel: No hotel found
# Caravelas - nearest hotel: No hotel found
# Boende - nearest hotel: No hotel found
# Vila Velha - nearest hotel: No hotel found
# Hilo - nearest hotel: No hotel found
# Berbera - nearest hotel: No hotel found
# Kruisfontein - nearest hotel: No hotel found
# Acapulco de Juárez - nearest hotel: No hotel found
# Sainte-Rose - nearest hotel: No hotel found
# Paramonga - nearest hotel: No hotel found
# Jérémie - nearest hotel: No hotel found
# Beloha - nearest hotel: No hotel found
# Saint-Pierre - nearest hotel: No hotel found
# Puerto Ayora - nearest hotel: No hotel found
# Gamba - nearest hotel: No hotel found
# Tuatapere - nearest hotel: No hotel found
# Cabo San Lucas - nearest hotel: No hotel found
# Kaeo - nearest hotel: No hotel found
# Ahipara - nearest hotel: No hotel found
# Ngunguru - nearest hotel: No hotel found
# Mundo Nuevo (Ojo de Agua) - nearest hotel: No hotel found
# Nacala - nearest hotel: No hotel found
# Omboué - nearest hotel: No hotel found
# Bengkulu - nearest hotel: No hotel found
# Kalmunai - nearest hotel: No hotel found
# Labuhan - nearest hotel: No hotel found
# San Fernando del Valle de Catamarca - nearest hotel: No hotel found
# Ca Mau - nearest hotel: No hotel found
# Maceió - nearest hotel: No hotel found
# Puerto Escondido - nearest hotel: No hotel found
# Carutapera - nearest hotel: No hotel found
# Tutóia - nearest hotel: No hotel found
# Russell - nearest hotel: No hotel found
# Natal - nearest hotel: No hotel found
# Puerto Maldonado - nearest hotel: No hotel found
